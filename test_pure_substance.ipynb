# %%
from thermodynamics.pure.equilibrium import solve_eos,solve_VLE

# %%
temperatura_critica =369.83#K
presion_critica = 42.48 # dato en Pascales dividir entre 100 000 para obtener bar
factor_acentrico = 0.152
ctes_cp=('16', (37840.4, -445.5789, 11.83871, 0.000653764, -2.2e-07))
#3994.325	-48.69006	10.36209	-0.000340144	1.96033E-07

p=10
T=300

#(t,p,tc,pc,acentric,method='pr',alfa='alfa_peng_robinson',diagram=False,properties=False,heat_capacity=None
solve_eos(T,p,temperatura_critica,presion_critica,factor_acentrico,method='pr',alfa_function='alfa_peng_robinson',properties=True,heat_capacity=ctes_cp)
#solve_VLE(T,p,temperatura_critica,presion_critica,factor_acentrico,solving_for='pressure')
# Out:
# {'liq_fugacity': 8.408201914989494,
#  'vap_fugacity': 8.421184379270057,
#  'enthalpy_liq': -15963.185979981714,
#  'enthalpy_vap': -1214.9303386166523,
#  'entropy_liq': -51.787458620252714,
#  'entropy_vap': -2.6394335965077076,
#  'z_liq': 0.034782742171078206,
#  'z_vap': 0.8146260906483427}

# %%
T=300
p=15
solve_VLE(T,p,temperatura_critica,presion_critica,factor_acentrico,solving_for='temperature')
# Out:
# 317.02059245323034

# %%
from thermodynamics.pure.diagrams import pv
T=300 # K 

pv(T,temperatura_critica,presion_critica,factor_acentrico)
# Out:
# 0

# %%
from thermodynamics.pure.diagrams import tv
p=20 # bar

tv(p,temperatura_critica,presion_critica,factor_acentrico)
# Out:
# 0

# %%
from thermodynamics.pure.diagrams import pt

pt(temperatura_critica,presion_critica,factor_acentrico,p_0=200)

# %%
from thermodynamics.pure.diagrams import pvt
temperatura_critica =469.15 #K
presion_critica = 71.9 # bar
factor_acentrico = 0.197447
pvt(temperatura_critica,presion_critica,factor_acentrico)
