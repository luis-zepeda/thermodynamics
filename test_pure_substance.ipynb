# %%
from thermodynamics.pure.equilibrium import solve_eos,solve_VLE

# %%
temperatura_critica =647.14 #K
presion_critica = 22064000/100000 # dato en Pascales dividir entre 100 000 para obtener bar
factor_acentrico = 0.344
ctes_cp=('4',(5083.56,225.639,-0.0999265,1.33106E-05))
#3994.325	-48.69006	10.36209	-0.000340144	1.96033E-07
print(presion_critica)
p=1
T=300

#(t,p,tc,pc,acentric,method='pr',alfa='alfa_peng_robinson',diagram=False,properties=False,heat_capacity=None
solve_eos(T,p,temperatura_critica,presion_critica,factor_acentrico,method='rks',alfa_function='soave',properties=True,heat_capacity=ctes_cp)
#solve_VLE(T,p,temperatura_critica,presion_critica,factor_acentrico,solving_for='temperature')
# Out:
# 220.64
# cp:  64141.26119999999
# ideal_enthalpy:  127.94373389753093
# ideal_entropy:  0.42790579637879694
# dAdt:  -0.008101189753943265
# residual_enthalpy:  -46903.89138078132
# residual_enthalpy:  -97.77664548323139
# residual_entropy:  -126.18740530320751
# residual_entropy:  -0.20163634499386396
# enthalpy_liq:  -46775.94764688379
# enthalpy_vap:  30.167088414299542
# entropy_liq:  -125.75949950682872
# entropy_vap:  0.22626945138493298
# (421281546.0028799, 1.0170423141573661)

# %%
from thermodynamics.pure.diagrams import pv

pv(T,temperatura_critica,presion_critica,factor_acentrico)
# Out:
# 0

# %%
from thermodynamics.pure.diagrams import tv

tv(p,temperatura_critica,presion_critica,factor_acentrico)
# Out:
# 0

# %%
from thermodynamics.pure.diagrams import pt

pt(temperatura_critica,presion_critica,factor_acentrico,p_0=200)

# %%
from thermodynamics.pure.diagrams import pvt
pvt(temperatura_critica,presion_critica,factor_acentrico)
